# %%
import pandas as pd

# %% [markdown]
# # Safety Neurons

# %%
df = pd.read_json("C:/Users/stian/ITU/MiniProject/train.jsonl.gz", lines=True, compression='gzip')

# %%
df.shape
# Out:
# (42537, 2)
